# %%
1+1
# Out:
# 2

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)


#每个批次大小
batch_size = 50

#计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size

#placeholders
x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None,10])

#a simple NN
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
prediction = tf.nn.softmax(tf.matmul(x,W) +b)

#loss = tf.reduce_mean(tf.square(y - prediction))
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

init = tf.global_variables_initializer()

correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction,1))

#accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(51):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys})
        acc = sess.run(accuracy, feed_dict={x:mnist.test.images, y:mnist.test.labels})
        print('Iter' + str(epoch) + ',Testing Accuracy' + str(acc))
# Out:
# WARNING:tensorflow:From <ipython-input-2-7a2b9f0dd4c1>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\ZSZ\Anaconda3\envs\ForDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\ZSZ\Anaconda3\envs\ForDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# ...

# %%
Iter0,Testing Accuracy0.8708
Iter1,Testing Accuracy0.8877
Iter2,Testing Accuracy0.8967
Iter3,Testing Accuracy0.9013
Iter4,Testing Accuracy0.9047
Iter5,Testing Accuracy0.9067
Iter6,Testing Accuracy0.9097
Iter7,Testing Accuracy0.9113
Iter8,Testing Accuracy0.9121
Iter9,Testing Accuracy0.9133
Iter10,Testing Accuracy0.9149
Iter11,Testing Accuracy0.916
Iter12,Testing Accuracy0.917
Iter13,Testing Accuracy0.9179
Iter14,Testing Accuracy0.9183
Iter15,Testing Accuracy0.9185
Iter16,Testing Accuracy0.9184
Iter17,Testing Accuracy0.9186
Iter18,Testing Accuracy0.9189
Iter19,Testing Accuracy0.9192
Iter20,Testing Accuracy0.9195
Iter21,Testing Accuracy0.9204
Iter22,Testing Accuracy0.9209
Iter23,Testing Accuracy0.9214
Iter24,Testing Accuracy0.9218
Iter25,Testing Accuracy0.9219
Iter26,Testing Accuracy0.922
Iter27,Testing Accuracy0.9221
Iter28,Testing Accuracy0.9221
Iter29,Testing Accuracy0.923
Iter30,Testing Accuracy0.9233
Iter31,Testing Accuracy0.9231
Iter32,Testing Accuracy0.9227
Iter33,Testing Accuracy0.9238
Iter34,Testing Accuracy0.9242
Iter35,Testing Accuracy0.9248
Iter36,Testing Accuracy0.9248
Iter37,Testing Accuracy0.9235
Iter38,Testing Accuracy0.9244
Iter39,Testing Accuracy0.9245
Iter40,Testing Accuracy0.9245
Iter41,Testing Accuracy0.9246
Iter42,Testing Accuracy0.9248
Iter43,Testing Accuracy0.9249
Iter44,Testing Accuracy0.9257
Iter45,Testing Accuracy0.9259
Iter46,Testing Accuracy0.9256
Iter47,Testing Accuracy0.9255
Iter48,Testing Accuracy0.9257
Iter49,Testing Accuracy0.926
Iter50,Testing Accuracy0.9255
